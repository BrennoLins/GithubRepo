# %% [markdown]
# # Análise - Empresa de Mídia
#
# Esse notebook foi criado para analisar os dados de uma empresa de mídia hipotética.
#
# Os objetivos são:
# - Investigar o que pode estar causando a queda na audiência da empresa e demonstrar como seria a série de pageviews caso esse problema fosse resolvido.
# - Fazer uma previsão do número de pageviews dos dias 5, 6 e 7 de maio.

# %% [markdown]
# Sumário
#
# 1. Descrição do problema
# 2. Análise exploratória dos dados
# 3. Pré-processamento
# 4. Análise da queda de pageviews
# 5. Simulação do problema resolvido
# 6. Previsão de pageviews
# 7. Conclusão

# %% [markdown]
# # 1. Descrição do problema

# %% [markdown]
# Para entender o comportamento da audiência, a empresa acompanha algumas métricas como: pageviews, usuários e sessões.
#
# Um usuário pode acessar uma página e consumir os conteúdos do site, cada página que o usuário abre corresponde a um pageview e cada vez que ele navega em um conjunto de páginas corresponde a uma sessão.
#
# De acordo com o gráfico, há uma tendência de queda na principal métrica de audiência, o número de pageviews.
#
# <img src="https://raw.githubusercontent.com/BrennoLins/GithubRepo/main/grafico_desafio.png" width="450">
#
# Para descobrir a causa desse problema, vamos investigar se existe uma relação da queda de pageviews com alguma variável específica, ou se a queda é proporcional em todos os recortes possíveis.
#
# Após determinada a principal causa do problema, será realizada uma simulação da série de pageviews caso esse problema fosse resolvido.
#
# Por fim, faremos uma previsão do número de pageviews total dos dias 5, 6 e 7 de maio com base nos dados passados.

# %% [markdown]
# # 2. Análise exploratória dos dados

# %% [markdown]
# Realizaremos a análise exploratória dos dados para compreender a natureza dos dados, observar a relação entre as métricas e identificar problemas como dados faltantes ou inconsistentes.
#
# O dataset possui 834,810 linhas e as seguintes colunas:
#
# - date: data de observação da audiência. O dataset vai de 01/jan/2021 a 03/mai/2021.
#
# - hits_hour: horário de observação da audiência. hits_hour = 10 significa que está agregando de 10h00 até 10h59.
#
# - geoNetwork_region: Unidade da Federação.
#
# - device_deviceCategory: dispositivo utilizado.
#
# - editoria: agrupamento de matérias por assunto. Este dataset possui um total de 39 editorias.
#
# - trafficSource_medium: A mídia da origem de tráfego.
#
# - trafficSource_source: A origem do tráfego.
#
# - variable: tipo de métrica (pageviews, usuários ou sessões).
#
# - value: valor da métrica.

# %%
# importações
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
from scipy.interpolate import make_interp_spline
from fbprophet import Prophet
from fbprophet.diagnostics import cross_validation
from fbprophet.diagnostics import performance_metrics

# leitura do arquivo com os dados
df = pd.read_csv('/kaggle/input/dados-desafio/dados_desafio.csv')

# %%
# visualização das primeiras linhas do dataset
df.head()
# Out:
#        date  hits_hour geoNetwork_region device_deviceCategory     editoria  \
# 0  20210101          0  Federal District                mobile  editoria_01
# 1  20210101          0  Federal District                mobile  editoria_01
# 2  20210101          0  Federal District                mobile  editoria_01
# 3  20210101          0  Federal District                mobile  editoria_01
# 4  20210101          0  Federal District                mobile  editoria_01
#
#   trafficSource_medium trafficSource_source   variable  value
# 0               (none)             (direct)   usuarios     14
# 1               (none)             (direct)    sessoes     15
# 2               (none)             (direct)  pageviews     18
# 3              organic               google   usuarios     14
# 4              organic               google    sessoes     15

# %% [markdown]
# As datas não estão no formato ideal.

# %%
# visualização dos data types e da contagem de não nulos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 834810 entries, 0 to 834809
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   date                   834810 non-null  object
#  1   hits_hour              834810 non-null  int64
#  2   geoNetwork_region      834810 non-null  object
#  3   device_deviceCategory  834810 non-null  object
#  4   editoria               834810 non-null  object
#  5   trafficSource_medium   834810 non-null  object
#  6   trafficSource_source   834810 non-null  object
#  7   variable               834810 non-null  object
#  8   value                  834810 non-null  int64
# dtypes: int64(2), object(7)
# memory usage: 57.3+ MB

# %% [markdown]
# Não existem valores nulos.

# %%
# descrição das tendências das variáveis numéricas
df.describe().style.format('{:,.2f}')
# Out:
# <style  type="text/css" >
# </style><table id="T_8dcfe_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >hits_hour</th>        <th class="col_heading level0 col1" >value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8dcfe_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_8dcfe_row0_col0" class="data row0 col0" >834,810.00</td>
#                         <td id="T_8dcfe_row0_col1" class="data row0 col1" >834,810.00</td>
#             </tr>
#             <tr>
#                         <th id="T_8dcfe_level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_8dcfe_row1_col0" class="data row1 col0" >14.21</td>
#                         <td id="T_8dcfe_row1_col1" class="data row1 col1" >48.67</td>
#             </tr>
#             <tr>
#                         <th id="T_8dcfe_level0_row2" class="row_heading level0 row2" >std</th>
#                         <td id="T_8dcfe_row2_col0" class="data row2 col0" >5.85</td>
#                         <td id="T_8dcfe_row2_col1" class="data row2 col1" >99.94</td>
#             </tr>
#             <tr>
#                         <th id="T_8dcfe_level0_row3" class="row_heading level0 row3" >min</th>
#                         <td id="T_8dcfe_row3_col0" class="data row3 col0" >0.00</td>
#                         <td id="T_8dcfe_row3_col1" class="data row3 col1" >1.00</td>
#             </tr>
#             <tr>
#                         <th id="T_8dcfe_level0_row4" class="row_heading level0 row4" >25%</th>
#                         <td id="T_8dcfe_row4_col0" class="data row4 col0" >10.00</td>
#                         <td id="T_8dcfe_row4_col1" class="data row4 col1" >16.00</td>
#             </tr>
#             <tr>
#                         <th id="T_8dcfe_level0_row5" class="row_heading level0 row5" >50%</th>
#                         <td id="T_8dcfe_row5_col0" class="data row5 col0" >15.00</td>
#                         <td id="T_8dcfe_row5_col1" class="data row5 col1" >24.00</td>
#             </tr>
#             <tr>
#                         <th id="T_8dcfe_level0_row6" class="row_heading level0 row6" >75%</th>
#                         <td id="T_8dcfe_row6_col0" class="data row6 col0" >19.00</td>
#                         <td id="T_8dcfe_row6_col1" class="data row6 col1" >46.00</td>
#             </tr>
#             <tr>
#                         <th id="T_8dcfe_level0_row7" class="row_heading level0 row7" >max</th>
#                         <td id="T_8dcfe_row7_col0" class="data row7 col0" >23.00</td>
#                         <td id="T_8dcfe_row7_col1" class="data row7 col1" >8,048.00</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# A variável value possui valor máximo muito acima da média, mas esse valor não é um outlier. Quando há algum furo de reportagem ou matéria polêmica, a audiência é muito maior que o normal.

# %%
# visualização da contagem dos valores das variáveis
for i in df.columns:
    print('---------------------------------------\n')
    print(df[[i]].value_counts())
    print()
# Out:
# ---------------------------------------
#
# date
# 20210117       12546
# 20210402       10335
# 20210314       10212
# 20210120        9954
# 20210123        9909
#                ...
# 16-jan-2021        3
# 31-mar-2021        3
# 01-fev-2021        3
# 01-abr-2021        3
# 25-abr-2021        2
# Length: 516, dtype: int64
#
# ---------------------------------------
#
# hits_hour
# 20           53138
# 21           52258
# 19           51336
# 18           49101
# 16           47788
# 22           47593
# 17           47395
# 13           47034
# 14           46666
# 15           46634
# 12           43877
# 11           41715
# 10           38873
# 9            37214
# 8            35526
# 23           35070
# 7            31328
# 0            22699
# 6            22031
# 1            11442
# 5            10546
# 2             6267
# 4             5037
# 3             4242
# dtype: int64
#
# ---------------------------------------
#
# geoNetwork_region
# State of Sao Paulo              226612
# State of Rio de Janeiro          92478
# State of Minas Gerais            82599
# State of Parana                  53285
# State of Rio Grande do Sul       50956
# State of Bahia                   45061
# State of Santa Catarina          35928
# State of Pernambuco              31008
# Federal District                 30168
# State of Ceara                   28734
# State of Goias                   24634
# State of Espirito Santo          20033
# State of Para                    18744
# State of Mato Grosso do Sul      14548
# State of Maranhao                13940
# State of Rio Grande do Norte     13610
# State of Mato Grosso             12213
# State of Amazonas                11278
# State of Paraiba                  9310
# State of Piaui                    6356
# State of Alagoas                  5389
# State of Sergipe                  3395
# State of Rondonia                 2083
# State of Tocantins                1983
# State of Amapa                     401
# State of Roraima                    46
# State of Acre                       18
# dtype: int64
#
# ---------------------------------------
#
# device_deviceCategory
# mobile                   776547
# desktop                   54849
# tablet                     3414
# dtype: int64
#
# ---------------------------------------
#
# editoria
# editoria_01     205794
# editoria_02     176217
# editoria_03      82203
# editoria_04      50054
# editoria_05      43351
# editoria_06      40503
# editoria_08      33989
# editoria_07      31435
# editoria_09      25212
# editoria_10      22423
# editoria_11      20336
# editoria_12      20226
# editoria_13      13629
# editoria_14      10371
# editoria_15       9981
# editoria_16       5961
# editeria_01       5558
# editoria_17       4371
# editoria_18       4364
# editoria_19       4053
# editoria_07       3908
# editoria_20       3807
# editoria_21       2910
# editoria_22       2223
# Editoria_05       1738
# editoria_23       1344
# editoria_24       1218
# editoria_25       1023
# editoria_26        879
# editoria_27        756
# editoria_28        630
# editoria_29        605
# editoria_30        506
# editoria_31        468
# editoria_32        434
# editoria_34        392
# editoria_33        369
# editoria_35        336
# editoria_36        333
# editoria 11        274
# editoria_37        262
# editoria_38        202
# editoria_39        162
# dtype: int64
#
# ---------------------------------------
#
# trafficSource_medium
# (none)                  371317
# organic                 309972
# referral                138526
# (not set)                 9897
# pushnotification          4023
# social                     960
# feed                       103
# cpc                         12
# dtype: int64
#
# ---------------------------------------
#
# trafficSource_source
# (direct)                371317
# google                  309340
# facebook                 68467
# googleapis.com           49672
# news.google.com          13242
# paywall                   9554
# twitter                   6740
# pushnews                  4044
# taboola                    929
# bing                       617
# instagram                  371
# whatsapp                   328
# yahoo                      189
# dtype: int64
#
# ---------------------------------------
#
# variable
# sessoes      282959
# usuarios     282959
# pageviews    268892
# dtype: int64
#
# ---------------------------------------
#
# value
# 15       42708
# 14       40289
# 16       38346
# 17       34220
# 18       31317
#          ...
# 1568         1
# 1561         1
# 1556         1
# 1551         1
# 8048         1
# Length: 1797, dtype: int64

# %% [markdown]
# As datas estão em diversos formatos diferentes.
#
# Algumas editorias estão com pequenos erros no nome.
#
# Podemos perceber que existe relação entre trafficSource_medium (mídia da origem de tráfego) e trafficSource_source (origem do tráfego).
#
# Também é possível perceber que existe relação entre os tipos de métrica (pageviews, usuários e sessões).

# %% [markdown]
# # 3. Pré-processamento

# %% [markdown]
# Nessa etapa será feita a limpeza dos dados, a seleção de características, a transformação de variáveis e outros tratamentos, caso necessários.

# %%
# formatação das datas

# substituição do mês pela forma numérica
df['date'] = df['date'].str.replace('jan', '01')
df['date'] = df['date'].str.replace('fev', '02')
df['date'] = df['date'].str.replace('mar', '03')
df['date'] = df['date'].str.replace('abr', '04')
df['date'] = df['date'].str.replace('mai', '05')

# substituição de - por /
df['date'] = df['date'].str.replace('-', '/')

# substituição de 21 por 2021 nas datas que começam com o ano
df['date'] = df['date'].str.replace(r'^21(/\d\d/\d\d)$', r'2021\1', regex=True)

# substituição de 21 por 2021 nas datas que terminam com o ano
df['date'] = df['date'].str.replace(r'^(\d\d/\d\d/)21$', r'\g<1>2021', regex=True)

# inversão das datas de dd/mm/yyyy para yyyy/mm/dd
df['date'] = df['date'].str.replace(r'^(\d\d)/(\d\d)/2021', r'2021/\2/\1', regex=True)

# remoção da /
df['date'] = df['date'].str.replace('/', '')

# visualização das datas
df['date'].value_counts()
# Out:
# 20210117    12864
# 20210314    11112
# 20210402    11010
# 20210305    10404
# 20210123    10176
#             ...
# 20210209     3609
# 20210206     3582
# 20210424     3548
# 20210425     3392
# 20210205     3180
# Name: date, Length: 123, dtype: int64

# %%
# conversão do tipo da data para datetime64
df['date'] = pd.to_datetime(df.date)

# %%
# correção das editorias
df['editoria'] = df['editoria'].str.replace('editeria_01', 'editoria_01')
df['editoria'] = df['editoria'].str.replace('editoria_07 ', 'editoria_07')
df['editoria'] = df['editoria'].str.replace('Editoria_05', 'editoria_05')
df['editoria'] = df['editoria'].str.replace('editoria 11', 'editoria_11')

# %%
# a variável hits_hour não é relevante porque vamos analisar o total de pageviews do dia

# remoção da coluna hits_hour
df_sem_hit = df.drop('hits_hour', 1)

# %%
# queremos analisar pageviews, usuários e sessões separadamente

# filtro de pageviews na coluna variable
df_pag = df_sem_hit[(df_sem_hit['variable'] == 'pageviews')]
# exclusão da coluna variable
df_pag = df_pag.drop('variable', 1)
# alteração do nome da coluna value
df_pag = df_pag.rename(columns = {'value': 'value_pag'})

# filtro de usuários na coluna variable
df_usu = df_sem_hit[(df_sem_hit['variable'] == 'usuarios')]
# exclusão da coluna variable
df_usu = df_usu.drop('variable', 1)
# alteração do nome da coluna value
df_usu = df_usu.rename(columns = {'value': 'value_usu'})

# filtro de sessões na coluna variable
df_ses = df_sem_hit[(df_sem_hit['variable'] == 'sessoes')]
# exclusão da coluna variable
df_ses = df_ses.drop('variable', 1)
# alteração do nome da coluna value
df_ses = df_ses.rename(columns = {'value': 'value_ses'})

# %%
# agrupamento das linhas, somando value

df_pag = df_pag.groupby([
    'date',
    'geoNetwork_region',
    'device_deviceCategory',
    'editoria',
    'trafficSource_medium',
    'trafficSource_source'
    ]).agg({'value_pag': 'sum'}).reset_index()

df_usu = df_usu.groupby([
    'date',
    'geoNetwork_region',
    'device_deviceCategory',
    'editoria',
    'trafficSource_medium',
    'trafficSource_source'
    ]).agg({'value_usu': 'sum'}).reset_index()

df_ses = df_ses.groupby([
    'date',
    'geoNetwork_region',
    'device_deviceCategory',
    'editoria',
    'trafficSource_medium',
    'trafficSource_source'
    ]).agg({'value_ses': 'sum'}).reset_index()

# %%
# visualização do número de pageviews por dia
df_pag_d = df_pag.set_index('date')
df_pag_d = df_pag_d['value_pag'].resample('D').sum()
df_pag_d.plot();

# %% [markdown]
# Existe um intervalo em abril onde o número de pageviews foi zero. Será necessário realizar tratamento de missings.

# %%
# faremos o tratamento de missings de pageviews usando como base o valor de sessões ou de usuários

# união de df_pag, df_usu e df_ses

df_metricas_separadas = pd.merge(
    df_usu,
    df_ses,
    how = 'outer',
    on = ['date', 'geoNetwork_region', 'device_deviceCategory', 'editoria', 'trafficSource_medium', 'trafficSource_source'])

df_metricas_separadas = pd.merge(
    df_metricas_separadas,
    df_pag,how = 'outer',
    on = ['date', 'geoNetwork_region', 'device_deviceCategory', 'editoria', 'trafficSource_medium', 'trafficSource_source'])

# visualização das primeiras linhas
df_metricas_separadas.head()
# Out:
#         date geoNetwork_region device_deviceCategory     editoria  \
# 0 2021-01-01  Federal District               desktop  editoria_11
# 1 2021-01-01  Federal District               desktop  editoria_12
# 2 2021-01-01  Federal District                mobile  editoria_01
# 3 2021-01-01  Federal District                mobile  editoria_01
# 4 2021-01-01  Federal District                mobile  editoria_01
#
#   trafficSource_medium trafficSource_source  value_usu  value_ses  value_pag
# 0              organic               google          1          1       14.0
# 1              organic               google          1          1       14.0
# 2               (none)             (direct)        820        833      996.0
# 3              organic               google        725        729      870.0
# 4             referral       googleapis.com        380        380      465.0

# %%
# correlação entre pageviews, sessões e usuários
df_metricas_separadas.corr().style.format('{:,.3f}')
# Out:
# <style  type="text/css" >
# </style><table id="T_dd7c5_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >value_usu</th>        <th class="col_heading level0 col1" >value_ses</th>        <th class="col_heading level0 col2" >value_pag</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dd7c5_level0_row0" class="row_heading level0 row0" >value_usu</th>
#                         <td id="T_dd7c5_row0_col0" class="data row0 col0" >1.000</td>
#                         <td id="T_dd7c5_row0_col1" class="data row0 col1" >0.890</td>
#                         <td id="T_dd7c5_row0_col2" class="data row0 col2" >0.999</td>
#             </tr>
#             <tr>
#                         <th id="T_dd7c5_level0_row1" class="row_heading level0 row1" >value_ses</th>
#                         <td id="T_dd7c5_row1_col0" class="data row1 col0" >0.890</td>
#                         <td id="T_dd7c5_row1_col1" class="data row1 col1" >1.000</td>
#                         <td id="T_dd7c5_row1_col2" class="data row1 col2" >0.887</td>
#             </tr>
#             <tr>
#                         <th id="T_dd7c5_level0_row2" class="row_heading level0 row2" >value_pag</th>
#                         <td id="T_dd7c5_row2_col0" class="data row2 col0" >0.999</td>
#                         <td id="T_dd7c5_row2_col1" class="data row2 col1" >0.887</td>
#                         <td id="T_dd7c5_row2_col2" class="data row2 col2" >1.000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# A correlação de pageviews com usuários é maior do que a de pageviews com sessões.
#
# Usaremos o valor de usuários como base para preencher os missings de pageviews.

# %%
# cálculo da relação entre a média de pageviews e de usuários
coef = df_metricas_separadas['value_pag'].mean() / df_metricas_separadas['value_usu'].mean()
coef
# Out:
# 1.2541930385740836

# %%
# substituição dos missings por value_usu multiplicado pelo coeficiente calculado
df_metricas_separadas['value_pag'].fillna(df_metricas_separadas['value_usu'] * coef, inplace = True)

# transformação de value_pag em integer
df_metricas_separadas['value_pag'] = df_metricas_separadas['value_pag'].astype(int)

# %%
# remoção das colunas value_ses e value_usu
df_tratado = df_metricas_separadas.drop(['value_ses', 'value_usu'], 1)

# visualização das primeiras linhas do dataset tratado
df_tratado.head()
# Out:
#         date geoNetwork_region device_deviceCategory     editoria  \
# 0 2021-01-01  Federal District               desktop  editoria_11
# 1 2021-01-01  Federal District               desktop  editoria_12
# 2 2021-01-01  Federal District                mobile  editoria_01
# 3 2021-01-01  Federal District                mobile  editoria_01
# 4 2021-01-01  Federal District                mobile  editoria_01
#
#   trafficSource_medium trafficSource_source  value_pag
# 0              organic               google         14
# 1              organic               google         14
# 2               (none)             (direct)        996
# 3              organic               google        870
# 4             referral       googleapis.com        465

# %%
# visualização do número de pageviews por dia após o tratamento de missings
df_tratado_d = df_tratado.set_index('date')
df_tratado_d = df_tratado_d['value_pag'].resample('D').sum()
df_tratado_d.plot();

# %%
# criação de uma coluna de mês
df_tratado['mes'] = df_tratado['date'].dt.month

# número de pageviews por mês após o tratamento de missings
df_tratado.groupby(['mes']).agg({'value_pag': 'sum'})
# Out:
#      value_pag
# mes
# 1      4219600
# 2      3085372
# 3      4546943
# 4      3450714
# 5       182918

# %% [markdown]
# # 4. Análise da queda de pageviews

# %% [markdown]
# Para descobrir a causa da queda de pageviews, vamos analisar a quantidade de pageviews por mês de cada variável, separadamente, dividindo o total de pageviews do mês pelo número de dias daquele mês, para obter o número médio de pageviews por dia.

# %%
# criação de uma lista com a quantidade de dias de cada mês
n_dias = [31, 28, 31, 30, 3]

# %%
# visualização do número médio de pageviews por dia de cada mês para a variável geoNetwork_region

df_pivot = pd.pivot_table(
    df_tratado,
    index = 'mes',
    columns = 'geoNetwork_region',
    values = 'value_pag',
    aggfunc = np.sum,
    fill_value = 0)

for i in range(5):
    df_pivot.loc[i+1] = df_pivot.loc[i+1] / n_dias[i]

pd.set_option('display.max_columns', None)
df_pivot.style.format('{:,.0f}').bar(width = 95, vmin = 0, vmax = 56172)
# Out:
# <style  type="text/css" >
# #T_ac674_row0_col0,#T_ac674_row2_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.1%, transparent 5.1%);
#         }#T_ac674_row0_col1,#T_ac674_row1_col1,#T_ac674_row1_col22,#T_ac674_row4_col1,#T_ac674_row4_col3,#T_ac674_row4_col22{
#             width:  10em;
#              height:  80%;
#         }#T_ac674_row0_col2,#T_ac674_row4_col10{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.5%, transparent 0.5%);
#         }#T_ac674_row0_col3,#T_ac674_row0_col26,#T_ac674_row1_col21,#T_ac674_row1_col26,#T_ac674_row4_col25{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.1%, transparent 0.1%);
#         }#T_ac674_row0_col4,#T_ac674_row2_col9{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.4%, transparent 2.4%);
#         }#T_ac674_row0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.1%, transparent 10.1%);
#         }#T_ac674_row0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.6%, transparent 4.6%);
#         }#T_ac674_row0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.3%, transparent 3.3%);
#         }#T_ac674_row0_col8,#T_ac674_row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.3%, transparent 4.3%);
#         }#T_ac674_row0_col9{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.6%, transparent 1.6%);
#         }#T_ac674_row0_col10,#T_ac674_row3_col10{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.4%, transparent 1.4%);
#         }#T_ac674_row0_col11,#T_ac674_row1_col13,#T_ac674_row2_col11{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.1%, transparent 2.1%);
#         }#T_ac674_row0_col12{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 26.0%, transparent 26.0%);
#         }#T_ac674_row0_col13,#T_ac674_row4_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.7%, transparent 2.7%);
#         }#T_ac674_row0_col14,#T_ac674_row1_col4,#T_ac674_row3_col14{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.1%, transparent 1.1%);
#         }#T_ac674_row0_col15{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 13.1%, transparent 13.1%);
#         }#T_ac674_row0_col16{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.5%, transparent 5.5%);
#         }#T_ac674_row0_col17,#T_ac674_row4_col18{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.6%, transparent 0.6%);
#         }#T_ac674_row0_col18,#T_ac674_row3_col11,#T_ac674_row4_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.8%, transparent 1.8%);
#         }#T_ac674_row0_col19{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.5%, transparent 12.5%);
#         }#T_ac674_row0_col20{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 29.3%, transparent 29.3%);
#         }#T_ac674_row0_col21,#T_ac674_row2_col21,#T_ac674_row3_col21,#T_ac674_row3_col26,#T_ac674_row4_col2,#T_ac674_row4_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.2%, transparent 0.2%);
#         }#T_ac674_row0_col22,#T_ac674_row1_col3,#T_ac674_row2_col1,#T_ac674_row2_col3,#T_ac674_row2_col22,#T_ac674_row3_col1,#T_ac674_row3_col3,#T_ac674_row3_col22,#T_ac674_row4_col21,#T_ac674_row4_col26{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0.0%);
#         }#T_ac674_row0_col23{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.7%, transparent 7.7%);
#         }#T_ac674_row0_col24{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 93.5%, transparent 93.5%);
#         }#T_ac674_row0_col25,#T_ac674_row1_col25,#T_ac674_row2_col26,#T_ac674_row4_col14{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.3%, transparent 0.3%);
#         }#T_ac674_row1_col2,#T_ac674_row1_col17,#T_ac674_row2_col25,#T_ac674_row3_col25,#T_ac674_row4_col17{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.4%, transparent 0.4%);
#         }#T_ac674_row1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.0%, transparent 10.0%);
#         }#T_ac674_row1_col6,#T_ac674_row3_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.9%, transparent 3.9%);
#         }#T_ac674_row1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.5%, transparent 2.5%);
#         }#T_ac674_row1_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.5%, transparent 3.5%);
#         }#T_ac674_row1_col9,#T_ac674_row1_col10,#T_ac674_row1_col11,#T_ac674_row2_col14{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.5%, transparent 1.5%);
#         }#T_ac674_row1_col12{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.2%, transparent 20.2%);
#         }#T_ac674_row1_col14,#T_ac674_row2_col17,#T_ac674_row4_col11{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.9%, transparent 0.9%);
#         }#T_ac674_row1_col15{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.2%, transparent 10.2%);
#         }#T_ac674_row1_col16{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.8%, transparent 4.8%);
#         }#T_ac674_row1_col18{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.3%, transparent 1.3%);
#         }#T_ac674_row1_col19{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.6%, transparent 9.6%);
#         }#T_ac674_row1_col20{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 21.1%, transparent 21.1%);
#         }#T_ac674_row1_col23{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.2%, transparent 6.2%);
#         }#T_ac674_row1_col24{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 78.7%, transparent 78.7%);
#         }#T_ac674_row2_col0,#T_ac674_row3_col16,#T_ac674_row4_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.9%, transparent 5.9%);
#         }#T_ac674_row2_col2,#T_ac674_row3_col2,#T_ac674_row4_col9{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.7%, transparent 0.7%);
#         }#

# %%
# visualização do número médio de pageviews por dia de cada mês para a variável device_deviceCategory

df_pivot = pd.pivot_table(
    df_tratado,
    index = 'mes',
    columns = 'device_deviceCategory',
    values = 'value_pag',
    aggfunc = np.sum,
    fill_value = 0)

for i in range(5):
    df_pivot.loc[i+1] = df_pivot.loc[i+1] / n_dias[i]

df_pivot.style.format('{:,.0f}').bar(width = 95, vmin = 0, vmax = 141617)
# Out:
# <style  type="text/css" >
# #T_7f1eb_row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.5%, transparent 1.5%);
#         }#T_7f1eb_row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 89.8%, transparent 89.8%);
#         }#T_7f1eb_row0_col2,#T_7f1eb_row1_col2,#T_7f1eb_row3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.1%, transparent 0.1%);
#         }#T_7f1eb_row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.0%, transparent 2.0%);
#         }#T_7f1eb_row1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 71.8%, transparent 71.8%);
#         }#T_7f1eb_row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.2%, transparent 3.2%);
#         }#T_7f1eb_row2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 95.0%, transparent 95.0%);
#         }#T_7f1eb_row2_col2,#T_7f1eb_row4_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.2%, transparent 0.2%);
#         }#T_7f1eb_row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.3%, transparent 3.3%);
#         }#T_7f1eb_row3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 73.7%, transparent 73.7%);
#         }#T_7f1eb_row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.8%, transparent 1.8%);
#         }#T_7f1eb_row4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 38.9%, transparent 38.9%);
#         }</style><table id="T_7f1eb_" ><thead>    <tr>        <th class="index_name level0" >device_deviceCategory</th>        <th class="col_heading level0 col0" >desktop</th>        <th class="col_heading level0 col1" >mobile</th>        <th class="col_heading level0 col2" >tablet</th>    </tr>    <tr>        <th class="index_name level0" >mes</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7f1eb_level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_7f1eb_row0_col0" class="data row0 col0" >2,185</td>
#                         <td id="T_7f1eb_row0_col1" class="data row0 col1" >133,826</td>
#                         <td id="T_7f1eb_row0_col2" class="data row0 col2" >105</td>
#             </tr>
#             <tr>
#                         <th id="T_7f1eb_level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_7f1eb_row1_col0" class="data row1 col0" >2,952</td>
#                         <td id="T_7f1eb_row1_col1" class="data row1 col1" >107,034</td>
#                         <td id="T_7f1eb_row1_col2" class="data row1 col2" >206</td>
#             </tr>
#             <tr>
#                         <th id="T_7f1eb_level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_7f1eb_row2_col0" class="data row2 col0" >4,773</td>
#                         <td id="T_7f1eb_row2_col1" class="data row2 col1" >141,617</td>
#                         <td id="T_7f1eb_row2_col2" class="data row2 col2" >286</td>
#             </tr>
#             <tr>
#                         <th id="T_7f1eb_level0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_7f1eb_row3_col0" class="data row3 col0" >4,945</td>
#                         <td id="T_7f1eb_row3_col1" class="data row3 col1" >109,866</td>
#                         <td id="T_7f1eb_row3_col2" class="data row3 col2" >213</td>
#             </tr>
#             <tr>
#                         <th id="T_7f1eb_level0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_7f1eb_row4_col0" class="data row4 col0" >2,682</td>
#                         <td id="T_7f1eb_row4_col1" class="data row4 col1" >57,997</td>
#                         <td id="T_7f1eb_row4_col2" class="data row4 col2" >294</td>
#             </tr>
#     </tbody></table>

# %%
# visualização do número médio de pageviews por dia de cada mês para a variável editoria

df_pivot = pd.pivot_table(
    df_tratado,
    index = 'mes',
    columns = 'editoria',
    values = 'value_pag',
    aggfunc = np.sum,
    fill_value = 0)

for i in range(5):
    df_pivot.loc[i+1] = df_pivot.loc[i+1] / n_dias[i]

df_pivot.style.format('{:,.0f}').bar(width = 95, vmin = 0, vmax = 66550)
# Out:
# <style  type="text/css" >
# #T_00801_row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 95.0%, transparent 95.0%);
#         }#T_00801_row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 18.1%, transparent 18.1%);
#         }#T_00801_row0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 17.9%, transparent 17.9%);
#         }#T_00801_row0_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 15.3%, transparent 15.3%);
#         }#T_00801_row0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.5%, transparent 3.5%);
#         }#T_00801_row0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.9%, transparent 5.9%);
#         }#T_00801_row0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 13.1%, transparent 13.1%);
#         }#T_00801_row0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.1%, transparent 5.1%);
#         }#T_00801_row0_col8,#T_00801_row1_col4,#T_00801_row2_col11{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.5%, transparent 2.5%);
#         }#T_00801_row0_col9,#T_00801_row2_col18{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.8%, transparent 1.8%);
#         }#T_00801_row0_col10,#T_00801_row0_col11,#T_00801_row0_col22,#T_00801_row1_col9,#T_00801_row1_col12{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.9%, transparent 0.9%);
#         }#T_00801_row0_col12{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.3%, transparent 4.3%);
#         }#T_00801_row0_col13,#T_00801_row0_col23{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.1%, transparent 1.1%);
#         }#T_00801_row0_col14,#T_00801_row0_col27,#T_00801_row0_col28,#T_00801_row0_col32,#T_00801_row0_col33,#T_00801_row1_col19,#T_00801_row1_col27,#T_00801_row1_col29,#T_00801_row1_col34,#T_00801_row1_col35,#T_00801_row2_col23,#T_00801_row2_col25,#T_00801_row2_col27,#T_00801_row2_col31,#T_00801_row2_col34,#T_00801_row3_col13,#T_00801_row3_col19,#T_00801_row3_col20,#T_00801_row3_col28,#T_00801_row3_col37,#T_00801_row3_col38,#T_00801_row4_col0,#T_00801_row4_col17{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.1%, transparent 0.1%);
#         }#T_00801_row0_col15{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.2%, transparent 1.2%);
#         }#T_00801_row0_col16,#T_00801_row0_col18,#T_00801_row1_col17,#T_00801_row1_col18,#T_00801_row2_col19,#T_00801_row3_col16,#T_00801_row3_col26,#T_00801_row3_col30,#T_00801_row4_col16{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.2%, transparent 0.2%);
#         }#T_00801_row0_col17,#T_00801_row3_col25{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.5%, transparent 0.5%);
#         }#T_00801_row0_col19{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.4%, transparent 2.4%);
#         }#T_00801_row0_col20{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.0%, transparent 1.0%);
#         }#T_00801_row0_col21,#T_00801_row3_col14{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.7%, transparent 0.7%);
#         }#T_00801_row0_col24,#T_00801_row0_col37,#T_00801_row1_col22,#T_00801_row1_col24,#T_00801_row1_col37,#T_00801_row2_col22,#T_00801_row2_col24,#T_00801_row2_col32,#T_00801_row2_col35,#T_00801_row2_col37,#T_00801_row3_col15,#T_00801_row3_col21,#T_00801_row3_col22,#T_00801_row3_col24,#T_00801_row3_col27,#T_00801_row3_col32,#T_00801_row3_col34,#T_00801_row3_col35,#T_00801_row4_col15,#T_00801_row4_col20,#T_00801_row4_col21,#T_00801_row4_col22,#T_00801_row4_col23,#T_00801_row4_col26,#T_00801_row4_col28,#T_00801_row4_col30,#T_00801_row4_col31,#T_00801_row4_col33,#T_00801_row4_col34,#T_00801_row4_col35,#T_00801_row4_col36,#T_00801_row4_col37,#T_00801_row4_col38{
#             width:  10em;
#              height:  80%;
#         }#T_00801_row0_col25,#T_00801_row0_col26,#T_00801_row0_col29,#T_00801_row0_col30,#T_00801_row0_col31,#T_00801_row0_col34,#T_00801_row0_col35,#T_00801_row0_col36,#T_00801_row0_col38,#T_00801_row1_col21,#T_00801_row1_col23,#T_00801_row1_col25,#T_00801_row1_col26,#T_00801_row1_col28,#T_00801_row1_col30,#T_00801_row1_col31,#T_00801_row1_col32,#T_00801_row1_col33,#T_00801_row1_col36,#T_00801_row1_col38,#T_00801_row2_col20,#T_00801_row2_col26,#T_00801_row2_col28,#T_00801_row2_col29,#T_00801_row2_col30,#T_00801_row2_col33,#T_00801_row2_col36,#T_00801_row2_col38,#T_00801_row3_col17,#T_00801_row3_col23,#T_00801_row3_col29,#T_00801_row3_col31,#T_00801_row3_col33,#T_00801_row3_col36,#T_00801_row4_col12,#T_00801_row4_col18,#T_00801_row4_col19,#T_00801_row4_col25,#T_00801_row4_col27,#T_00801_row4_col29,#T_00801_row4_col32{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0.0%);
#         }#T_00801_row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 48.2%, transparent 48.2%);
#         }#T_00801_row1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 40.9%, transparent 40.9%);
#         }#T_00801_row1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 21.7%, transparent 21.7%);
#         }#T_00801_row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 17.1%, transparent 17.1%);
#         }#T_00801_row1_col5,#T_00801_row2_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.2%, transparent 3.2%);
#         }#T_00801_row1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.5%, transparent 6.5%);
#         }#T_00801_row1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.2%, transparent 4.2%);
#         }#T_00801_row1_col8,#T_00801_row2_col10{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.6%, transparent 2.6%);
#         }#T_00801_row1_col10,#T_00801_row2_col17{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.7%, transparent 1.7%);
#         }#T_00801_row1_col11,#T_00801_row3_col12{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.6%, transparent 1.6%);
#         }#T_00801_row1_col13,#T_00801_row1_col20{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.4%, transparent 0.4%);
#         }#T_00801_row1_col14,#T_00801_row2_col16,#T_00801_row2_col21,#T_00801_row4_col7,#T_00801_row4_col14{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.6%, transparent 0.6%);
#         }#T_00801_row1_col15,#T_00801_row4_col10,#T_00801_row4_col11{
#             width:  10em;

# %% [markdown]
# A editoria_01 foi a que teve mais pageviews no primeiro trimestre, mas sofreu uma queda e praticamente não teve pageviews em maio.

# %%
# visualização do número médio de pageviews por dia de cada mês para a variável trafficSource_medium

df_pivot = pd.pivot_table(
    df_tratado,
    index = 'mes',
    columns = 'trafficSource_medium',
    values = 'value_pag',
    aggfunc = np.sum,
    fill_value = 0)

for i in range(5):
    df_pivot.loc[i+1] = df_pivot.loc[i+1] / n_dias[i]

df_pivot.style.format('{:,.0f}').bar(width = 95, vmin = 0, vmax = 89488)
# Out:
# <style  type="text/css" >
# #T_33666_row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 67.9%, transparent 67.9%);
#         }#T_33666_row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.4%, transparent 0.4%);
#         }#T_33666_row0_col2,#T_33666_row0_col3,#T_33666_row1_col2,#T_33666_row1_col3,#T_33666_row3_col2,#T_33666_row4_col3,#T_33666_row4_col7{
#             width:  10em;
#              height:  80%;
#         }#T_33666_row0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 44.3%, transparent 44.3%);
#         }#T_33666_row0_col5,#T_33666_row4_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.2%, transparent 0.2%);
#         }#T_33666_row0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 31.4%, transparent 31.4%);
#         }#T_33666_row0_col7,#T_33666_row1_col5,#T_33666_row1_col7,#T_33666_row3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.3%, transparent 0.3%);
#         }#T_33666_row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 65.0%, transparent 65.0%);
#         }#T_33666_row1_col1,#T_33666_row2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.5%, transparent 0.5%);
#         }#T_33666_row1_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 36.8%, transparent 36.8%);
#         }#T_33666_row1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 14.1%, transparent 14.1%);
#         }#T_33666_row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 95.0%, transparent 95.0%);
#         }#T_33666_row2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.8%, transparent 0.8%);
#         }#T_33666_row2_col2,#T_33666_row2_col3,#T_33666_row2_col7,#T_33666_row3_col3,#T_33666_row3_col7,#T_33666_row4_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0.0%);
#         }#T_33666_row2_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 47.3%, transparent 47.3%);
#         }#T_33666_row2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.0%, transparent 12.0%);
#         }#T_33666_row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 76.0%, transparent 76.0%);
#         }#T_33666_row3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.7%, transparent 0.7%);
#         }#T_33666_row3_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 35.7%, transparent 35.7%);
#         }#T_33666_row3_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.4%, transparent 9.4%);
#         }#T_33666_row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 41.9%, transparent 41.9%);
#         }#T_33666_row4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.6%, transparent 0.6%);
#         }#T_33666_row4_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 19.6%, transparent 19.6%);
#         }#T_33666_row4_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.4%, transparent 2.4%);
#         }</style><table id="T_33666_" ><thead>    <tr>        <th class="index_name level0" >trafficSource_medium</th>        <th class="col_heading level0 col0" >(none)</th>        <th class="col_heading level0 col1" >(not set)</th>        <th class="col_heading level0 col2" >cpc</th>        <th class="col_heading level0 col3" >feed</th>        <th class="col_heading level0 col4" >organic</th>        <th class="col_heading level0 col5" >pushnotification</th>        <th class="col_heading level0 col6" >referral</th>        <th class="col_heading level0 col7" >social</th>    </tr>    <tr>        <th class="index_name level0" >mes</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_33666_level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_33666_row0_col0" class="data row0 col0" >63,917</td>
#                         <td id="T_33666_row0_col1" class="data row0 col1" >353</td>
#                         <td id="T_33666_row0_col2" class="data row0 col2" >0</td>
#                         <td id="T_33666_row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_33666_row0_col4" class="data row0 col4" >41,746</td>
#                         <td id="T_33666_row0_col5" class="data row0 col5" >220</td>
#                         <td id="T_33666_row0_col6" class="data row0 col6" >29,604</td>
#                         <td id="T_33666_row0_col7" class="data row0 col7" >277</td>
#             </tr>
#             <tr>
#                         <th id="T_33666_level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_33666_row1_col0" class="data row1 col0" >61,184</td>
#                         <td id="T_33666_row1_col1" class="data row1 col1" >476</td>
#                         <td id="T_33666_row1_col2" class="data row1 col2" >0</td>
#                         <td id="T_33666_row1_col3" class="data row1 col3" >0</td>
#                         <td id="T_33666_row1_col4" class="data row1 col4" >34,694</td>
#                         <td id="T_33666_row1_col5" class="data row1 col5" >257</td>
#                         <td id="T_33666_row1_col6" class="data row1 col6" >13,284</td>
#                         <td id="T_33666_row1_col7" class="data row1 col7" >297</td>
#             </tr>
#             <tr>
#                         <th id="T_33666_level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_33666_row2_col0" class="data row2 col0" >89,488</td>
#                         <td id="T_33666_row2_col1" class="data row2 col1" >780</td>
#                         <td id="T_33666_row2_col2" class="data row2 col2" >1</td>
#                         <td id="T_33666_row2_col3" class="data row2 col3" >5</td>
#                         <td id="T_33666_row2_col4" class="data row2 col4" >44,599</td>
#                         <td id="T_33666_row2_col5" class="data row2 col5" >505</td>
#                         <td id="T_33666_row2_col6" class="data row2 col6" >11,272</td>
#                         <td id="T_33666_row2_col7" class="data row2 col7" >25</td>
#             </tr>
#             <tr>
#                         <th id="T_33666_level0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_33666_row3_col0" class="data row3 col0" >71,621</td>
#                         <td id="T_33666_row3_col1" class="data row3 col1" >622</td>
#                         <td id="T_33666_row3_col2" class="data row3 col2" >0</td>
#                         <td id="T_33666_row3_col3" class="data row3 col3" >20</td>
#                         <td id="T_33666_row3_col4" class="d

# %%
# visualização do número médio de pageviews por dia de cada mês para a variável trafficSource_source

df_pivot = pd.pivot_table(
    df_tratado,
    index = 'mes',
    columns = 'trafficSource_source',
    values = 'value_pag',
    aggfunc = np.sum,
    fill_value = 0)

for i in range(5):
    df_pivot.loc[i+1] = df_pivot.loc[i+1] / n_dias[i]

df_pivot.style.format('{:,.0f}').bar(width = 95, vmin = 0, vmax = 89488)
# Out:
# <style  type="text/css" >
# #T_f560f_row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 67.9%, transparent 67.9%);
#         }#T_f560f_row0_col1,#T_f560f_row0_col5,#T_f560f_row0_col11,#T_f560f_row0_col12,#T_f560f_row1_col1,#T_f560f_row1_col5,#T_f560f_row1_col9,#T_f560f_row1_col11,#T_f560f_row1_col12,#T_f560f_row2_col1,#T_f560f_row2_col5,#T_f560f_row2_col9,#T_f560f_row2_col11,#T_f560f_row2_col12,#T_f560f_row3_col1,#T_f560f_row3_col9,#T_f560f_row3_col11,#T_f560f_row3_col12,#T_f560f_row4_col5,#T_f560f_row4_col6,#T_f560f_row4_col9,#T_f560f_row4_col10{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0.0%);
#         }#T_f560f_row0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.5%, transparent 9.5%);
#         }#T_f560f_row0_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 44.3%, transparent 44.3%);
#         }#T_f560f_row0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.6%, transparent 20.6%);
#         }#T_f560f_row0_col6,#T_f560f_row2_col4,#T_f560f_row2_col7,#T_f560f_row3_col10{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.8%, transparent 0.8%);
#         }#T_f560f_row0_col7,#T_f560f_row1_col8,#T_f560f_row1_col10,#T_f560f_row3_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.3%, transparent 0.3%);
#         }#T_f560f_row0_col8,#T_f560f_row3_col4,#T_f560f_row4_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.2%, transparent 0.2%);
#         }#T_f560f_row0_col9,#T_f560f_row3_col5,#T_f560f_row4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.1%, transparent 0.1%);
#         }#T_f560f_row0_col10,#T_f560f_row2_col10{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.7%, transparent 0.7%);
#         }#T_f560f_row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 65.0%, transparent 65.0%);
#         }#T_f560f_row1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.3%, transparent 7.3%);
#         }#T_f560f_row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 36.8%, transparent 36.8%);
#         }#T_f560f_row1_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.9%, transparent 5.9%);
#         }#T_f560f_row1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.9%, transparent 0.9%);
#         }#T_f560f_row1_col7,#T_f560f_row2_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.5%, transparent 0.5%);
#         }#T_f560f_row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 95.0%, transparent 95.0%);
#         }#T_f560f_row2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.0%, transparent 9.0%);
#         }#T_f560f_row2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 47.3%, transparent 47.3%);
#         }#T_f560f_row2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.4%, transparent 1.4%);
#         }#T_f560f_row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 76.0%, transparent 76.0%);
#         }#T_f560f_row3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.2%, transparent 7.2%);
#         }#T_f560f_row3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 35.6%, transparent 35.6%);
#         }#T_f560f_row3_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.1%, transparent 1.1%);
#         }#T_f560f_row3_col7,#T_f560f_row4_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.6%, transparent 0.6%);
#         }#T_f560f_row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 41.9%, transparent 41.9%);
#         }#T_f560f_row4_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.3%, transparent 2.3%);
#         }#T_f560f_row4_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 19.6%, transparent 19.6%);
#         }#T_f560f_row4_col4,#T_f560f_row4_col11,#T_f560f_row4_col12{
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_f560f_" ><thead>    <tr>        <th class="index_name level0" >trafficSource_source</th>        <th class="col_heading level0 col0" >(direct)</th>        <th class="col_heading level0 col1" >bing</th>        <th class="col_heading level0 col2" >facebook</th>        <th class="col_heading level0 col3" >google</th>        <th class="col_heading level0 col4" >googleapis.com</th>        <th class="col_heading level0 col5" >instagram</th>        <th class="col_heading level0 col6" >news.google.com</th>        <th class="col_heading level0 col7" >paywall</th>        <th class="col_heading level0 col8" >pushnews</th>        <th class="col_heading level0 col9" >taboola</th>        <th class="col_heading level0 col10" >twitter</th>        <th class="col_heading level0 col11" >whatsapp</th>        <th class="col_heading level0 col12" >yahoo</th>    </tr>    <tr>        <th class="index_name level0" >mes</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f560f_level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_f560f_row0_col0" class="data row0 col0" >63,917</td>
#                         <td id="T_f560f_row0_col1" class="data row0 col1" >27</td>
#                         <td id="T_f560f_row0_col2" class="data row0 col2" >8,930</td>
#                         <td id="T_f560f_row0_col3" class="data row0 col3" >41,715</td>
#                         <td id="T_f560f_row0_col4" class="data row0 col4" >19,396</td>
#                         <td id="T_f560f_row0_col5" class="data row0 col5" >0</td>
#                         <td id="T_f560f_row0_col6" class="data row0 col6" >780</td>
#                         <td id="T_f560f_row0_col7" class="data row0 col7" >325</td>
#                         <td id="T_f560f_row0_col8" class="data row0 col8" >220</td>
#                         <td id="T_f560f_row0_col9" class="data row0 col9" >126</td>
#                         <td id="T_f560f_row0_col10" class="data row0 col10" >645</td>
#                         <td id="T_f560f_row0_col11" class="data row0 col11" >28</td>
#                         <td id="T_f560f_row0_col12" class="data row0 col12" >8</td>
#             </tr>
#             <tr>

# %% [markdown]
# Examinando todas as tabelas, foi concluído que a provável causa da queda de pageviews foi a queda na editoria_01.

# %%
# criação de um df com as colunas de mês, editoria e pageviews
df_ed = df_tratado[['mes', 'editoria', 'value_pag']]

# filtro de editoria_01
df_ed1 = df_ed[(df_ed['editoria'] == 'editoria_01')]

# agrupamento das linhas por mês, somando value
df_ed1 = df_ed1.groupby(['mes']).agg({'value_pag': 'sum'}).reset_index()

# cálculo da média diária
for i in range(5):
    df_ed1.loc[[i], ['value_pag']] = df_ed1.loc[[i], ['value_pag']] / n_dias[i]

# df com a média de pageviews por dia para cada mês da editoria_01
df_ed1.style.format('{:,.0f}').hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_bbc15_" ><thead>    <tr>        <th class="col_heading level0 col0" >mes</th>        <th class="col_heading level0 col1" >value_pag</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_bbc15_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_bbc15_row0_col1" class="data row0 col1" >66,550</td>
#             </tr>
#             <tr>
#                                 <td id="T_bbc15_row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_bbc15_row1_col1" class="data row1 col1" >33,781</td>
#             </tr>
#             <tr>
#                                 <td id="T_bbc15_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_bbc15_row2_col1" class="data row2 col1" >49,351</td>
#             </tr>
#             <tr>
#                                 <td id="T_bbc15_row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_bbc15_row3_col1" class="data row3 col1" >24,512</td>
#             </tr>
#             <tr>
#                                 <td id="T_bbc15_row4_col0" class="data row4 col0" >5</td>
#                         <td id="T_bbc15_row4_col1" class="data row4 col1" >93</td>
#             </tr>
#     </tbody></table>

# %%
# visualização da média de pageviews por dia para cada mês da editoria_01
x_y_Spline = make_interp_spline(df_ed1['mes'], df_ed1['value_pag'])
x_ = np.linspace(1, 5, 200)
y_ = x_y_Spline(x_)
plt.plot(x_, y_)
plt.axis([1, 5, 0, 74000])
plt.ylabel('Pageviews por dia')
plt.xlabel('Mês')
plt.title('Média de pageviews por dia da editoria_01')
plt.show()

# %% [markdown]
# # 5. Simulação do problema resolvido

# %% [markdown]
# Para realizar a simulação do problema resolvido, vamos alterar os valores dos pageviews da editoria_01 após março para acompanhar a variação dos pageviews das outras editorias.

# %%
# filtro excluindo editoria_01 do df_ed
df_sem_ed1 = df_ed[(df_ed['editoria'] != 'editoria_01')]

# agrupamento das linhas por mês, somando value
df_sem_ed1 = df_sem_ed1.groupby(['mes']).agg({'value_pag': 'sum'}).reset_index()

# cálculo da média diária
for i in range(5):
    df_sem_ed1.loc[[i], ['value_pag']] = df_sem_ed1.loc[[i], ['value_pag']] / n_dias[i]

# média diária de pageviews por mês das editorias (sem a editoria_01)
df_sem_ed1.style.format('{:,.0f}').hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_e2861_" ><thead>    <tr>        <th class="col_heading level0 col0" >mes</th>        <th class="col_heading level0 col1" >value_pag</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_e2861_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_e2861_row0_col1" class="data row0 col1" >69,566</td>
#             </tr>
#             <tr>
#                                 <td id="T_e2861_row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_e2861_row1_col1" class="data row1 col1" >76,411</td>
#             </tr>
#             <tr>
#                                 <td id="T_e2861_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_e2861_row2_col1" class="data row2 col1" >97,325</td>
#             </tr>
#             <tr>
#                                 <td id="T_e2861_row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_e2861_row3_col1" class="data row3 col1" >90,512</td>
#             </tr>
#             <tr>
#                                 <td id="T_e2861_row4_col0" class="data row4 col0" >5</td>
#                         <td id="T_e2861_row4_col1" class="data row4 col1" >60,879</td>
#             </tr>
#     </tbody></table>

# %%
# criação da coluna de crescimento percentual
df_sem_ed1['crescimento_pct'] = 1.0

# cálculo do crescimento percentual mensal
for i in range(4):
    df_sem_ed1.loc[i+1, 'crescimento_pct'] = df_sem_ed1['value_pag'][i+1] / df_sem_ed1['value_pag'][i]

# crescimento percentual mensal do número médio de pageviews por dia (sem a editoria_01)
format_dict = {'value_pag': '{:,.0f}', 'crescimento_pct': '{:.2%}'}
df_sem_ed1.style.format(format_dict).hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_9fbc5_" ><thead>    <tr>        <th class="col_heading level0 col0" >mes</th>        <th class="col_heading level0 col1" >value_pag</th>        <th class="col_heading level0 col2" >crescimento_pct</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_9fbc5_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_9fbc5_row0_col1" class="data row0 col1" >69,566</td>
#                         <td id="T_9fbc5_row0_col2" class="data row0 col2" >100.00%</td>
#             </tr>
#             <tr>
#                                 <td id="T_9fbc5_row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_9fbc5_row1_col1" class="data row1 col1" >76,411</td>
#                         <td id="T_9fbc5_row1_col2" class="data row1 col2" >109.84%</td>
#             </tr>
#             <tr>
#                                 <td id="T_9fbc5_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_9fbc5_row2_col1" class="data row2 col1" >97,325</td>
#                         <td id="T_9fbc5_row2_col2" class="data row2 col2" >127.37%</td>
#             </tr>
#             <tr>
#                                 <td id="T_9fbc5_row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_9fbc5_row3_col1" class="data row3 col1" >90,512</td>
#                         <td id="T_9fbc5_row3_col2" class="data row3 col2" >93.00%</td>
#             </tr>
#             <tr>
#                                 <td id="T_9fbc5_row4_col0" class="data row4 col0" >5</td>
#                         <td id="T_9fbc5_row4_col1" class="data row4 col1" >60,879</td>
#                         <td id="T_9fbc5_row4_col2" class="data row4 col2" >67.26%</td>
#             </tr>
#     </tbody></table>

# %%
# alteração dos valores de pageviews da editoria_01 em abril e maio
df_ed1_alterado = df_ed1.copy()
for i in range(2):
    df_ed1_alterado.loc[i+3, 'value_pag'] = df_ed1_alterado.loc[i+2, 'value_pag'] * df_sem_ed1.loc[i+3, 'crescimento_pct']

# transformação de value_pag em integer
df_ed1_alterado['value_pag'] = df_ed1_alterado['value_pag'].astype(int)

# média diária de pageviews por mês da editoria_01 (alterado)
df_ed1_alterado.style.format('{:,}').hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_cea2a_" ><thead>    <tr>        <th class="col_heading level0 col0" >mes</th>        <th class="col_heading level0 col1" >value_pag</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_cea2a_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_cea2a_row0_col1" class="data row0 col1" >66,549</td>
#             </tr>
#             <tr>
#                                 <td id="T_cea2a_row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_cea2a_row1_col1" class="data row1 col1" >33,781</td>
#             </tr>
#             <tr>
#                                 <td id="T_cea2a_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_cea2a_row2_col1" class="data row2 col1" >49,350</td>
#             </tr>
#             <tr>
#                                 <td id="T_cea2a_row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_cea2a_row3_col1" class="data row3 col1" >45,895</td>
#             </tr>
#             <tr>
#                                 <td id="T_cea2a_row4_col0" class="data row4 col0" >5</td>
#                         <td id="T_cea2a_row4_col1" class="data row4 col1" >30,870</td>
#             </tr>
#     </tbody></table>

# %%
# criação de um df com mês e pageviews para inserção dos valores alterados
df_alterado = df_tratado.groupby(['mes']).agg({'value_pag': 'sum'}).reset_index()

# cálculo da média diária
for i in range(5):
    df_alterado.loc[[i], ['value_pag']] = df_alterado.loc[[i], ['value_pag']] / n_dias[i]

# novo total = antigo total - antigo valor de editoria_01 + novo valor de editoria_01
for i in range(2):
    df_alterado.loc[i+3, 'value_pag'] = \
        df_alterado.loc[i+3, 'value_pag'] - \
        df_ed1.loc[i+3, 'value_pag'] + \
        df_ed1_alterado.loc[i+3, 'value_pag']

# %%
# comparação gráfica de antes e depois da alteração

# df com total de pageviews por mês (sem alteração)
df_sem_alteracao = df_tratado.groupby(['mes']).agg({'value_pag': 'sum'}).reset_index()

# cálculo da média diária
for i in range(5):
    df_sem_alteracao.loc[[i], ['value_pag']] = df_sem_alteracao.loc[[i], ['value_pag']] / n_dias[i]

# criação do gráfico da média diária de pageviews por mês (sem alteração)
xy_spline = make_interp_spline(df_sem_alteracao['mes'], df_sem_alteracao['value_pag'])
x = np.linspace(1, 5, 200)
y = xy_spline(x)
plt.plot(x, y, label='Antes da alteração')

# criação do gráfico da média diária de pageviews por mês (alterado)
x_y_spline = make_interp_spline(df_alterado['mes'], df_alterado['value_pag'])
y_ = x_y_spline(x)
plt.plot(x, y_, label='Depois da alteração')

# visualização da média diária de pageviews por mês, antes e depois da alteração
plt.axis([1, 5, 0, 185000])
plt.ylabel('Pageviews por dia')
plt.xlabel('Mês')
plt.title('Comparação da média diária de pageviews')
plt.legend(loc = "lower left")
plt.show()

# %%
# criação de um df para analisar a diferença de pageviews entre antes e depois da alteração dos valores da editoria_01
df_dif = df_sem_alteracao.copy()

# alteração do nome da coluna
df_dif = df_dif.rename(columns = {"value_pag": "value_pag_antes"})

# adição de uma coluna com os valores alterados
df_dif['value_pag_depois'] = df_alterado['value_pag']

# adição da coluna com a diferença
df_dif['diferenca'] = df_dif['value_pag_depois'] - df_dif['value_pag_antes']

# adição da coluna com o percentual da diferença
df_dif['diferenca_pct'] = df_dif['diferenca'] / df_dif['value_pag_antes']

# visualização da diferença de pageviews
format_dict = {
    'value_pag_antes': '{:,.0f}',
    'value_pag_depois': '{:,.0f}',
    'diferenca': '{:,.0f}',
    'diferenca_pct': '{:.2%}'}
df_dif.style.format(format_dict).hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_1e37d_" ><thead>    <tr>        <th class="col_heading level0 col0" >mes</th>        <th class="col_heading level0 col1" >value_pag_antes</th>        <th class="col_heading level0 col2" >value_pag_depois</th>        <th class="col_heading level0 col3" >diferenca</th>        <th class="col_heading level0 col4" >diferenca_pct</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_1e37d_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_1e37d_row0_col1" class="data row0 col1" >136,116</td>
#                         <td id="T_1e37d_row0_col2" class="data row0 col2" >136,116</td>
#                         <td id="T_1e37d_row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_1e37d_row0_col4" class="data row0 col4" >0.00%</td>
#             </tr>
#             <tr>
#                                 <td id="T_1e37d_row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_1e37d_row1_col1" class="data row1 col1" >110,192</td>
#                         <td id="T_1e37d_row1_col2" class="data row1 col2" >110,192</td>
#                         <td id="T_1e37d_row1_col3" class="data row1 col3" >0</td>
#                         <td id="T_1e37d_row1_col4" class="data row1 col4" >0.00%</td>
#             </tr>
#             <tr>
#                                 <td id="T_1e37d_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_1e37d_row2_col1" class="data row2 col1" >146,676</td>
#                         <td id="T_1e37d_row2_col2" class="data row2 col2" >146,676</td>
#                         <td id="T_1e37d_row2_col3" class="data row2 col3" >0</td>
#                         <td id="T_1e37d_row2_col4" class="data row2 col4" >0.00%</td>
#             </tr>
#             <tr>
#                                 <td id="T_1e37d_row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_1e37d_row3_col1" class="data row3 col1" >115,024</td>
#                         <td id="T_1e37d_row3_col2" class="data row3 col2" >136,407</td>
#                         <td id="T_1e37d_row3_col3" class="data row3 col3" >21,383</td>
#                         <td id="T_1e37d_row3_col4" class="data row3 col4" >18.59%</td>
#             </tr>
#             <tr>
#                                 <td id="T_1e37d_row4_col0" class="data row4 col0" >5</td>
#                         <td id="T_1e37d_row4_col1" class="data row4 col1" >60,973</td>
#                         <td id="T_1e37d_row4_col2" class="data row4 col2" >91,749</td>
#                         <td id="T_1e37d_row4_col3" class="data row4 col3" >30,777</td>
#                         <td id="T_1e37d_row4_col4" class="data row4 col4" >50.48%</td>
#             </tr>
#     </tbody></table>

# %%
# cálculo do total da diferença
print(n_dias[3] * 21383 + n_dias[4] * 30777)
# Out:
# 733821

# %% [markdown]
# No cenário onde o número de pageviews da editoria_01 segue a mesma variação das outras editorias em abril e em maio, o valor total de pageviews aumentou em 18% em abril e 50% em março, totalizando 733,821 pageviews a mais.

# %% [markdown]
# # 6. Previsão de pageviews

# %% [markdown]
# Para a previsão do total de pageviews até o dia 7 de maio, usaremos o software de previsão criado pelo Facebook, Prophet.
#
# O Prophet realiza previsões ajustando tendências não lineares à sazonalidade anual, semanal e diária, que podem ser ajustadas. O input é sempre um dataframe com duas colunas: ds e y. A coluna ds é a data e a coluna y representa a medida que desejamos prever.
#
# Avaliaremos a previsão utilizando validação cruzada, utilizando como métrica a raiz quadrada do erro médio (rmse, em inglês).
#
# Obs: Nessa etapa, a alteração dos pageviews da editoria_01 realizada na etapa anterior (Simulação do problema resolvido) não foi considerada.

# %%
# criação de um df com pageviews por dia para realizar a previsão
df_tratado_prev = df_tratado.groupby(['date']).agg({'value_pag': "sum"}).reset_index()

# alteração dos nomes das colunas
df_tratado_prev = df_tratado_prev.rename(columns = {"date": "ds", "value_pag": "y"})

# visualização das últimas linhas
format_dict = {'ds': '{:%Y-%m-%d}', 'y': '{:,}'}
df_tratado_prev.tail().style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_c70e5_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ds</th>        <th class="col_heading level0 col1" >y</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c70e5_level0_row0" class="row_heading level0 row0" >118</th>
#                         <td id="T_c70e5_row0_col0" class="data row0 col0" >2021-04-29</td>
#                         <td id="T_c70e5_row0_col1" class="data row0 col1" >74,261</td>
#             </tr>
#             <tr>
#                         <th id="T_c70e5_level0_row1" class="row_heading level0 row1" >119</th>
#                         <td id="T_c70e5_row1_col0" class="data row1 col0" >2021-04-30</td>
#                         <td id="T_c70e5_row1_col1" class="data row1 col1" >82,038</td>
#             </tr>
#             <tr>
#                         <th id="T_c70e5_level0_row2" class="row_heading level0 row2" >120</th>
#                         <td id="T_c70e5_row2_col0" class="data row2 col0" >2021-05-01</td>
#                         <td id="T_c70e5_row2_col1" class="data row2 col1" >49,860</td>
#             </tr>
#             <tr>
#                         <th id="T_c70e5_level0_row3" class="row_heading level0 row3" >121</th>
#                         <td id="T_c70e5_row3_col0" class="data row3 col0" >2021-05-02</td>
#                         <td id="T_c70e5_row3_col1" class="data row3 col1" >65,371</td>
#             </tr>
#             <tr>
#                         <th id="T_c70e5_level0_row4" class="row_heading level0 row4" >122</th>
#                         <td id="T_c70e5_row4_col0" class="data row4 col0" >2021-05-03</td>
#                         <td id="T_c70e5_row4_col1" class="data row4 col1" >67,687</td>
#             </tr>
#     </tbody></table>

# %%
# criação do modelo para previsão
modelo = Prophet(
    weekly_seasonality = 1,
    changepoint_prior_scale = 0.5,
    seasonality_prior_scale = 0.01)

# adição de uma sazonalidade mensal
modelo.add_seasonality(name = 'monthly', period = 30.5, fourier_order = 10)

# fourier order das sazonalidades mensal e semanal foi variado com os valores: [1, 3, 5, 10]
# changepoint e seasonality prior scale foram variados com os seguintes valores:
# changepoint_prior_scale [0.01, 0.1, 0.5]
# seasonality_prior_scale [0.01, 0.1, 1.0]
# a combinação escolhida para o modelo foi a que obteve a menor raiz quadrada do erro médio (rmse)

# adição de feriados
modelo.add_country_holidays(country_name = 'BR')

# ajuste do modelo
modelo.fit(df_tratado_prev)

# criação de um df com as datas a serem previstas
futuro = modelo.make_future_dataframe(periods = 4)

# previsão para cada data em futuro
previsao = modelo.predict(futuro)

# validação cruzada
df_vc = cross_validation(modelo, initial = '90 days', horizon = '4 days')

# avaliação da performance
df_perf = performance_metrics(df_vc)
print('rmse médio:', int(df_perf['rmse'].mean()))
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# rmse médio: 39577

# %%
# visualização da previsão
modelo.plot(previsao)
plt.title("Previsão de Pageviews")
plt.xlabel("Data")
plt.ylabel("Pageviews")
plt.show()

# %%
# visualização dos componentes da previsão
modelo.plot_components(previsao);

# %%
# transformação em integer
previsao[['yhat', 'yhat_lower', 'yhat_upper']] = \
    previsao[['yhat', 'yhat_lower', 'yhat_upper']].astype(int)

# visualização da previsão (yhat) e dos intervalos de incerteza
format_dict = {'ds': '{:%Y-%m-%d}', 'yhat': '{:,}', 'yhat_lower': '{:,}', 'yhat_upper': '{:,}'}
previsao[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail().style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_68165_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ds</th>        <th class="col_heading level0 col1" >yhat</th>        <th class="col_heading level0 col2" >yhat_lower</th>        <th class="col_heading level0 col3" >yhat_upper</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_68165_level0_row0" class="row_heading level0 row0" >122</th>
#                         <td id="T_68165_row0_col0" class="data row0 col0" >2021-05-03</td>
#                         <td id="T_68165_row0_col1" class="data row0 col1" >84,600</td>
#                         <td id="T_68165_row0_col2" class="data row0 col2" >28,736</td>
#                         <td id="T_68165_row0_col3" class="data row0 col3" >141,309</td>
#             </tr>
#             <tr>
#                         <th id="T_68165_level0_row1" class="row_heading level0 row1" >123</th>
#                         <td id="T_68165_row1_col0" class="data row1 col0" >2021-05-04</td>
#                         <td id="T_68165_row1_col1" class="data row1 col1" >78,235</td>
#                         <td id="T_68165_row1_col2" class="data row1 col2" >18,040</td>
#                         <td id="T_68165_row1_col3" class="data row1 col3" >136,009</td>
#             </tr>
#             <tr>
#                         <th id="T_68165_level0_row2" class="row_heading level0 row2" >124</th>
#                         <td id="T_68165_row2_col0" class="data row2 col0" >2021-05-05</td>
#                         <td id="T_68165_row2_col1" class="data row2 col1" >76,301</td>
#                         <td id="T_68165_row2_col2" class="data row2 col2" >16,263</td>
#                         <td id="T_68165_row2_col3" class="data row2 col3" >137,196</td>
#             </tr>
#             <tr>
#                         <th id="T_68165_level0_row3" class="row_heading level0 row3" >125</th>
#                         <td id="T_68165_row3_col0" class="data row3 col0" >2021-05-06</td>
#                         <td id="T_68165_row3_col1" class="data row3 col1" >79,422</td>
#                         <td id="T_68165_row3_col2" class="data row3 col2" >19,955</td>
#                         <td id="T_68165_row3_col3" class="data row3 col3" >137,934</td>
#             </tr>
#             <tr>
#                         <th id="T_68165_level0_row4" class="row_heading level0 row4" >126</th>
#                         <td id="T_68165_row4_col0" class="data row4 col0" >2021-05-07</td>
#                         <td id="T_68165_row4_col1" class="data row4 col1" >71,640</td>
#                         <td id="T_68165_row4_col2" class="data row4 col2" >13,637</td>
#                         <td id="T_68165_row4_col3" class="data row4 col3" >128,706</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# A previsão do total de pageviews é:
#
# - 76,301 de pageviews no dia 5 de maio
# - 79,422 de pageviews no dia 6 de maio
# - 71,640 de pageviews no dia 7 de maio

# %% [markdown]
# # 7. Conclusão

# %% [markdown]
# Nesse notebook, foi analisado o dataset de uma empresa de mídia hipotética. Para explicar a causa da queda na principal métrica de audiência, o número de pageviews, foi investigada a sua relação com as variáveis do dataset. Após a descoberta da principal causa do problema, foi realizada uma simulação da série de pageviews caso esse problema fosse resolvido. Além disso, foi feita a previsão do número de pageviews total dos dias 5, 6 e 7 de maio.
#
# Os resultados encontrados foram:
# - A redução do número de pageviews na editoria_01 a partir de abril foi a principal causa da queda na audiência da empresa. No primeiro trimestre, a editoria_01 foi a editoria com mais pageviews, mas o valor caiu de 49,351 por dia em março, para 93 por dia em maio. Na simulação do problema resolvido, a empresa teve 733,821 pageviews a mais nesse período.
# - A previsão de pageviews para os dias 5, 6 e 7 de maio é, respectivamente: 76,301, 79,422 e 71,640.
